# %% [markdown]
# # Resultados simulaciones
#
# Se revisan los resultados de las simulaciones del modelo original de Brian Arthur, barriendo los parámetros `numero de rondas de memoria` ($d$) y `tamaño bolsa predictores` ($k$).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from DatosGraficos import *

# %% [markdown]
# ## Simulaciones con 1 predictor variando memoria:

# %% [markdown]
# **Obtener datos**

# %%
memorias = [1, 3, 6, 9, 12]
predictores = [1]
conectividades = ['0']
data = leer_datos(memorias, predictores, conectividades)
data.head()
# Out:
# Leyendo datos sweep memoria 1 predictores 1 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-1-0.csv...
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3263: DtypeWarning: Columns (0,1,2,3,4,5,6,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Listo
# Leyendo datos sweep memoria 3 predictores 1 y conectividad 0
# Cargando datos de archivo ./data/simulacion-3-1-0.csv...
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:17: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
# Listo
# Leyendo datos sweep memoria 6 predictores 1 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-1-0.csv...
# Listo
# Leyendo datos sweep memoria 9 predictores 1 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-1-0.csv...
# Listo
# Leyendo datos sweep memoria 12 predictores 1 y conectividad 0
# Cargando datos de archivo ./data/simulacion-12-1-0.csv...
# Listo
# Preparando dataframe...
#   Memoria Num_predic Identificador Ronda Agente Estado Puntaje  \
# 1       1          1             0     0      0      1       1
# 2       1          1             0     1      0      1      -1
# 3       1          1             0     2      0      1       1
# 4       1          1             0     3      0      1      -1
# 5       1          1             0     4      0      1       1
#
#            Politica Prediccion Precision Conectividad
# 1  2-ciclico-espejo         42       NaN            0
# 2  2-ciclico-espejo          0      58.0            0
# 3  2-ciclico-espejo         43      57.0            0
# 4  2-ciclico-espejo          0      57.0            0
# 5  2-ciclico-espejo         43      57.0            0
# Shape: (5000000, 11)
# Memoria value counts: 12    1000000
# 9     1000000
# 6     1000000
# 3     1000000
# 1     1000000
# Name: Memoria, dtype: int64
# Predictores value counts: 1    5000000
# Name: Num_predic, dtype: int64
# Conectividades value counts: 0.0    5000000
# Name: Conectividad, dtype: int64
# Agente value counts: 99    50000
# 36    50000
# 26    50000
# 27    50000
# 28    50000
#       ...
# 69    50000
# 70    50000
# 71    50000
# 72    50000
# 0     50000
# Name: Agente, Length: 100, dtype: int64
#    Conectividad  Memoria  Num_predic  Identificador  Ronda  Agente  Estado  \
# 1           0.0        1           1              0      0       0       1
# 2           0.0        1           1              0      1       0       1
# 3           0.0        1           1              0      2       0       1
# 4           0.0        1           1              0      3       0       1
# 5           0.0        1           1              0      4       0       1
#
#    Puntaje          Politica  Prediccion  Precision
# 1        1  2-ciclico-espejo          42        NaN
# 2       -1  2-ciclico-espejo           0       58.0
# 3        1  2-ciclico-espejo          43       57.0
# 4       -1  2-ciclico-espejo           0       57.0
# 5        1  2-ciclico-espejo          43       57.0

# %% [markdown]
# **Asistencia**

# %%
dibuja_asistencia_vs(data, 'Memoria')

# %%
dibujar_puntaje_vs(data, 'Memoria')

# %% [markdown]
# **Uso de políticas**

# %%
dibuja_usopredictores_vs(data, 'Memoria')
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dibuja_puntajepredictor_vs(data, 'Memoria')

# %% [markdown]
# ## Simulaciones con 3 predictores variando memoria:

# %% [markdown]
# **Obtener datos**

# %%
memorias = [1, 3, 6, 9, 12]
predictores = [3]
conectividades = ['0']
data = leer_datos(memorias, predictores, conectividades)
data.head()
# Out:
# Leyendo datos sweep memoria 1 predictores 3 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-3-0.csv...
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3263: DtypeWarning: Columns (0,1,2,3,4,5,6,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Listo
# Leyendo datos sweep memoria 3 predictores 3 y conectividad 0
# Cargando datos de archivo ./data/simulacion-3-3-0.csv...
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:17: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
# Listo
# Leyendo datos sweep memoria 6 predictores 3 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-3-0.csv...
# Listo
# Leyendo datos sweep memoria 9 predictores 3 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-3-0.csv...
# Listo
# Leyendo datos sweep memoria 12 predictores 3 y conectividad 0
# Cargando datos de archivo ./data/simulacion-12-3-0.csv...
# Listo
# Preparando dataframe...
#   Memoria Num_predic Identificador Ronda Agente Estado Puntaje   Politica  \
# 1       1          3             0     0      0      0       0  2-ventana
# 2       1          3             0     1      0      1      -1  2-ventana
# 3       1          3             0     2      0      0       0  2-ventana
# 4       1          3             0     3      0      0       0  2-ventana
# 5       1          3             0     4      0      1       1  2-ventana
#
#   Prediccion Precision Conectividad
# 1         43       NaN            0
# 2        100      57.0            0
# 3         85      15.0            0
# 4         14      71.0            0
# 5         15       1.0            0
# Shape: (5000000, 11)
# Memoria value counts: 12    1000000
# 9     1000000
# 6     1000000
# 3     1000000
# 1     1000000
# Name: Memoria, dtype: int64
# Predictores value counts: 3    5000000
# Name: Num_predic, dtype: int64
# Conectividades value counts: 0.0    5000000
# Name: Conectividad, dtype: int64
# Agente value counts: 99    50000
# 36    50000
# 26    50000
# 27    50000
# 28    50000
#       ...
# 69    50000
# 70    50000
# 71    50000
# 72    50000
# 0     50000
# Name: Agente, Length: 100, dtype: int64
#    Conectividad  Memoria  Num_predic  Identificador  Ronda  Agente  Estado  \
# 1           0.0        1           3              0      0       0       0
# 2           0.0        1           3              0      1       0       1
# 3           0.0        1           3              0      2       0       0
# 4           0.0        1           3              0      3       0       0
# 5           0.0        1           3              0      4       0       1
#
#    Puntaje   Politica  Prediccion  Precision
# 1        0  2-ventana          43        NaN
# 2       -1  2-ventana         100       57.0
# 3        0  2-ventana          85       15.0
# 4        0  2-ventana          14       71.0
# 5        1  2-ventana          15        1.0

# %% [markdown]
# **Asistencia**

# %%
dibuja_asistencia_vs(data, 'Memoria')

# %% [markdown]
# #### Recompensa total

# %%
dibujar_puntaje_vs(data, 'Memoria')

# %% [markdown]
# **Uso de políticas**

# %%
dibuja_usopredictores_vs(data, 'Memoria')
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dibuja_puntajepredictor_vs(data, 'Memoria')

# %% [markdown]
# ## Simulaciones con 6 predictores variando memoria:

# %% [markdown]
# **Obtener datos**

# %%
memorias = [1, 3, 6, 9, 12]
predictores = [6]
conectividades = ['0']
data = leer_datos(memorias, predictores, conectividades)
data.head()
# Out:
# Leyendo datos sweep memoria 1 predictores 6 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-6-0.csv...
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:17: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
# Listo
# Leyendo datos sweep memoria 3 predictores 6 y conectividad 0
# Cargando datos de archivo ./data/simulacion-3-6-0.csv...
# Listo
# Leyendo datos sweep memoria 6 predictores 6 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-6-0.csv...
# Listo
# Leyendo datos sweep memoria 9 predictores 6 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-6-0.csv...
# Listo
# Leyendo datos sweep memoria 12 predictores 6 y conectividad 0
# Cargando datos de archivo ./data/simulacion-12-6-0.csv...
# Listo
# Preparando dataframe...
#    Memoria  Num_predic  Identificador  Ronda  Agente  Estado  Puntaje  \
# 0        1           6            200      0       0       0        0
# 1        1           6            200      1       0       1       -1
# 2        1           6            200      2       0       0        0
# 3        1           6            200      3       0       0        0
# 4        1           6            200      4       0       1       -1
#
#            Politica  Prediccion  Precision Conectividad
# 0  7-ventana-espejo          47        NaN            0
# 1         9-ciclico         100       47.0            0
# 2  7-ventana-espejo         100        0.0            0
# 3         9-ciclico           2        2.0            0
# 4  7-ventana-espejo           0        2.0            0
# Shape: (5000000, 11)
# Memoria value counts: 12    1000000
# 9     1000000
# 6     1000000
# 3     1000000
# 1     1000000
# Name: Memoria, dtype: int64
# Predictores value counts: 6    5000000
# Name: Num_predic, dtype: int64
# Conectividades value counts: 0.0    5000000
# Name: Conectividad, dtype: int64
# Agente value counts: 99    50000
# 36    50000
# 26    50000
# 27    50000
# 28    50000
#       ...
# 69    50000
# 70    50000
# 71    50000
# 72    50000
# 0     50000
# Name: Agente, Length: 100, dtype: int64
#    Conectividad  Memoria  Num_predic  Identificador  Ronda  Agente  Estado  \
# 0           0.0        1           6            200      0       0       0
# 1           0.0        1           6            200      1       0       1
# 2           0.0        1           6            200      2       0       0
# 3           0.0        1           6            200      3       0       0
# 4           0.0        1           6            200      4       0       1
#
#    Puntaje          Politica  Prediccion  Precision
# 0        0  7-ventana-espejo          47        NaN
# 1       -1         9-ciclico         100       47.0
# 2        0  7-ventana-espejo         100        0.0
# 3        0         9-ciclico           2        2.0
# 4       -1  7-ventana-espejo           0        2.0

# %% [markdown]
# **Asistencia**

# %%
dibuja_asistencia_vs(data, 'Memoria')

# %% [markdown]
# #### Recompensa total

# %%
dibujar_puntaje_vs(data, 'Memoria')

# %% [markdown]
# **Uso de políticas**

# %%
dibuja_usopredictores_vs(data, 'Memoria')
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dibuja_puntajepredictor_vs(data, 'Memoria')

# %% [markdown]
# ## Simulaciones con 9 predictores variando memoria:

# %% [markdown]
# **Obtener datos**

# %%
memorias = [1, 3, 6, 9, 12]
predictores = [9]
conectividades = ['0']
data = leer_datos(memorias, predictores, conectividades)
data.head()
# Out:
# Leyendo datos sweep memoria 1 predictores 9 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-9-0.csv...
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:17: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
# Listo
# Leyendo datos sweep memoria 3 predictores 9 y conectividad 0
# Cargando datos de archivo ./data/simulacion-3-9-0.csv...
# Listo
# Leyendo datos sweep memoria 6 predictores 9 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-9-0.csv...
# Listo
# Leyendo datos sweep memoria 9 predictores 9 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-9-0.csv...
# Listo
# Leyendo datos sweep memoria 12 predictores 9 y conectividad 0
# Cargando datos de archivo ./data/simulacion-12-9-0.csv...
# Listo
# Preparando dataframe...
#    Memoria  Num_predic  Identificador  Ronda  Agente  Estado  Puntaje  \
# 0        1           9            400      0       0       1        1
# 1        1           9            400      1       0       1       -1
# 2        1           9            400      2       0       1       -1
# 3        1           9            400      3       0       0        0
# 4        1           9            400      4       0       0        0
#
#            Politica  Prediccion  Precision Conectividad
# 0  2-ventana-espejo          51        NaN            0
# 1  2-ventana-espejo           0       49.0            0
# 2         2-ventana         100        0.0            0
# 3  2-ventana-espejo         100        0.0            0
# 4         2-ventana           0        0.0            0
# Shape: (5000000, 11)
# Memoria value counts: 12    1000000
# 9     1000000
# 6     1000000
# 3     1000000
# 1     1000000
# Name: Memoria, dtype: int64
# Predictores value counts: 9    5000000
# Name: Num_predic, dtype: int64
# Conectividades value counts: 0.0    5000000
# Name: Conectividad, dtype: int64
# Agente value counts: 99    50000
# 36    50000
# 26    50000
# 27    50000
# 28    50000
#       ...
# 69    50000
# 70    50000
# 71    50000
# 72    50000
# 0     50000
# Name: Agente, Length: 100, dtype: int64
#    Conectividad  Memoria  Num_predic  Identificador  Ronda  Agente  Estado  \
# 0           0.0        1           9            400      0       0       1
# 1           0.0        1           9            400      1       0       1
# 2           0.0        1           9            400      2       0       1
# 3           0.0        1           9            400      3       0       0
# 4           0.0        1           9            400      4       0       0
#
#    Puntaje          Politica  Prediccion  Precision
# 0        1  2-ventana-espejo          51        NaN
# 1       -1  2-ventana-espejo           0       49.0
# 2       -1         2-ventana         100        0.0
# 3        0  2-ventana-espejo         100        0.0
# 4        0         2-ventana           0        0.0

# %% [markdown]
# **Asistencia**

# %%
dibuja_asistencia_vs(data, 'Memoria')

# %% [markdown]
# #### Recompensa total

# %%
dibujar_puntaje_vs(data, 'Memoria')

# %% [markdown]
# **Uso de políticas**

# %%
dibuja_usopredictores_vs(data, 'Memoria')
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dibuja_puntajepredictor_vs(data, 'Memoria')
