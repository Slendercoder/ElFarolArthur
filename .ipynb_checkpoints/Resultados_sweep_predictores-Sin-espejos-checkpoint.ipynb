# %% [markdown]
# # Resultados simulaciones
#
# Se revisan los resultados de las simulaciones del modelo original de Brian Arthur, barriendo los parámetros `numero de rondas de memoria` ($d$) y `tamaño bolsa predictores` ($k$).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from DatosGraficos import *

# %% [markdown]
# ## Simulaciones con 1 memoria variando predictores:

# %% [markdown]
# **Obtener datos**

# %%
memorias = [1]
predictores = [1, 3, 6, 9, 12]
conectividades = ['0']
data = leer_datos(memorias, predictores, conectividades)
data.head()
# Out:
# Leyendo datos sweep memoria 1 predictores 1 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-1-0.csv...
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3263: DtypeWarning: Columns (0,1,2,3,4,5,6,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Listo
# Leyendo datos sweep memoria 1 predictores 3 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-3-0.csv...
# Listo
# Leyendo datos sweep memoria 1 predictores 6 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-6-0.csv...
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:17: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
# Listo
# Leyendo datos sweep memoria 1 predictores 9 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-9-0.csv...
# Listo
# Leyendo datos sweep memoria 1 predictores 12 y conectividad 0
# Cargando datos de archivo ./data/simulacion-1-12-0.csv...
# Listo
# Preparando dataframe...
#   Memoria Num_predic Identificador Ronda Agente Estado Puntaje  \
# 1       1          1             0     0      0      1       1
# 2       1          1             0     1      0      1      -1
# 3       1          1             0     2      0      1       1
# 4       1          1             0     3      0      1      -1
# 5       1          1             0     4      0      1       1
#
#            Politica Prediccion Precision Conectividad
# 1  2-ciclico-espejo         42       NaN            0
# 2  2-ciclico-espejo          0      58.0            0
# 3  2-ciclico-espejo         43      57.0            0
# 4  2-ciclico-espejo          0      57.0            0
# 5  2-ciclico-espejo         43      57.0            0
# Shape: (5000000, 11)
# Memoria value counts: 1    5000000
# Name: Memoria, dtype: int64
# Predictores value counts: 12    1000000
# 9     1000000
# 6     1000000
# 3     1000000
# 1     1000000
# Name: Num_predic, dtype: int64
# Conectividades value counts: 0.0    5000000
# Name: Conectividad, dtype: int64
# Agente value counts: 99    50000
# 36    50000
# 26    50000
# 27    50000
# 28    50000
#       ...
# 69    50000
# 70    50000
# 71    50000
# 72    50000
# 0     50000
# Name: Agente, Length: 100, dtype: int64
#    Conectividad  Memoria  Num_predic  Identificador  Ronda  Agente  Estado  \
# 1           0.0        1           1              0      0       0       1
# 2           0.0        1           1              0      1       0       1
# 3           0.0        1           1              0      2       0       1
# 4           0.0        1           1              0      3       0       1
# 5           0.0        1           1              0      4       0       1
#
#    Puntaje          Politica  Prediccion  Precision
# 1        1  2-ciclico-espejo          42        NaN
# 2       -1  2-ciclico-espejo           0       58.0
# 3        1  2-ciclico-espejo          43       57.0
# 4       -1  2-ciclico-espejo           0       57.0
# 5        1  2-ciclico-espejo          43       57.0

# %% [markdown]
# **Asistencia**

# %%
dibuja_asistencia_vs(data, 'Num_predic')

# %% [markdown]
# #### Recompensa total

# %%
dibujar_puntaje_vs(data, 'Num_predic')

# %% [markdown]
# **Uso de políticas**

# %%
dibuja_usopredictores_vs(data, 'Num_predic')
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dibuja_puntajepredictor_vs(data, 'Num_predic')

# %% [markdown]
# ## Simulaciones con 3 memoria y variando predictores:

# %% [markdown]
# **Obtener datos**

# %%
memorias = [3]
predictores = [1, 3, 6, 9, 12]
conectividades = ['0.01']
data = leer_datos(memorias, predictores, conectividades)
data.head()
# Out:
# Leyendo datos sweep memoria 3 predictores 1 y conectividad 0.01
# Cargando datos de archivo ./data/simulacion-3-1-0.01.csv...
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:17: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
# Listo
# Leyendo datos sweep memoria 3 predictores 3 y conectividad 0.01
# Cargando datos de archivo ./data/simulacion-3-3-0.01.csv...
# Listo
# Leyendo datos sweep memoria 3 predictores 6 y conectividad 0.01
# Cargando datos de archivo ./data/simulacion-3-6-0.01.csv...
# Listo
# Leyendo datos sweep memoria 3 predictores 9 y conectividad 0.01
# Cargando datos de archivo ./data/simulacion-3-9-0.01.csv...
# Listo
# Leyendo datos sweep memoria 3 predictores 12 y conectividad 0.01
# Cargando datos de archivo ./data/simulacion-3-12-0.01.csv...
# Listo
# Preparando dataframe...
#    Memoria  Num_predic  Identificador  Ronda  Agente  Estado  Puntaje  \
# 0        3           1            200      0       0       1        1
# 1        3           1            200      1       0       1       -1
# 2        3           1            200      2       0       0        0
# 3        3           1            200      3       0       0        0
# 4        3           1            200      4       0       0        0
#
#     Politica  Prediccion  Precision Conectividad
# 0  5-ventana          53        NaN         0.01
# 1  5-ventana          76  47.000000         0.01
# 2  5-ventana          70  32.500000         0.01
# 3  5-ventana          79  25.000000         0.01
# 4  5-ventana          65  16.333333         0.01
# Shape: (4590000, 11)
# Memoria value counts: 3    4590000
# Name: Memoria, dtype: int64
# Predictores value counts: 9     1000000
# 6     1000000
# 3     1000000
# 1     1000000
# 12     590000
# Name: Num_predic, dtype: int64
# Conectividades value counts: 0.01    4590000
# Name: Conectividad, dtype: int64
# Agente value counts: 99    45900
# 36    45900
# 26    45900
# 27    45900
# 28    45900
#       ...
# 69    45900
# 70    45900
# 71    45900
# 72    45900
# 0     45900
# Name: Agente, Length: 100, dtype: int64
#    Conectividad  Memoria  Num_predic  Identificador  Ronda  Agente  Estado  \
# 0          0.01        3           1            200      0       0       1
# 1          0.01        3           1            200      1       0       1
# 2          0.01        3           1            200      2       0       0
# 3          0.01        3           1            200      3       0       0
# 4          0.01        3           1            200      4       0       0
#
#    Puntaje   Politica  Prediccion  Precision
# 0        1  5-ventana          53        NaN
# 1       -1  5-ventana          76  47.000000
# 2        0  5-ventana          70  32.500000
# 3        0  5-ventana          79  25.000000
# 4        0  5-ventana          65  16.333333

# %% [markdown]
# **Asistencia**

# %%
dibuja_asistencia_vs(data, 'Num_predic')

# %% [markdown]
# #### Recompensa total

# %%
dibujar_puntaje_vs(data, 'Num_predic')

# %% [markdown]
# **Uso de políticas**

# %%
dibuja_usopredictores_vs(data, 'Num_predic')
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dibuja_puntajepredictor_vs(data, 'Num_predic')

# %% [markdown]
# ## Simulaciones con 6 memoria y variando predictores:

# %% [markdown]
# **Obtener datos**

# %%
memorias = [6]
predictores = [1, 3, 6, 9, 12]
conectividades = ['0']
data = leer_datos(memorias, predictores, conectividades)
data.head()
# Out:
# Leyendo datos sweep memoria 6 predictores 1 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-1-0.csv...
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:17: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
# Listo
# Leyendo datos sweep memoria 6 predictores 3 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-3-0.csv...
# Listo
# Leyendo datos sweep memoria 6 predictores 6 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-6-0.csv...
# Listo
# Leyendo datos sweep memoria 6 predictores 9 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-9-0.csv...
# Listo
# Leyendo datos sweep memoria 6 predictores 12 y conectividad 0
# Cargando datos de archivo ./data/simulacion-6-12-0.csv...
# Listo
# Preparando dataframe...
#    Memoria  Num_predic  Identificador  Ronda  Agente  Estado  Puntaje  \
# 0        6           1            600      0       0       0        0
# 1        6           1            600      1       0       1       -1
# 2        6           1            600      2       0       1        1
# 3        6           1            600      3       0       1       -1
# 4        6           1            600      4       0       1        1
#
#             Politica  Prediccion  Precision Conectividad
# 0  14-ciclico-espejo          51        NaN            0
# 1  14-ciclico-espejo           0       49.0            0
# 2  14-ciclico-espejo          47       51.0            0
# 3  14-ciclico-espejo          23       44.0            0
# 4  14-ciclico-espejo          47       40.5            0
# Shape: (5000000, 11)
# Memoria value counts: 6    5000000
# Name: Memoria, dtype: int64
# Predictores value counts: 12    1000000
# 9     1000000
# 6     1000000
# 3     1000000
# 1     1000000
# Name: Num_predic, dtype: int64
# Conectividades value counts: 0.0    5000000
# Name: Conectividad, dtype: int64
# Agente value counts: 99    50000
# 36    50000
# 26    50000
# 27    50000
# 28    50000
#       ...
# 69    50000
# 70    50000
# 71    50000
# 72    50000
# 0     50000
# Name: Agente, Length: 100, dtype: int64
#    Conectividad  Memoria  Num_predic  Identificador  Ronda  Agente  Estado  \
# 0           0.0        6           1            600      0       0       0
# 1           0.0        6           1            600      1       0       1
# 2           0.0        6           1            600      2       0       1
# 3           0.0        6           1            600      3       0       1
# 4           0.0        6           1            600      4       0       1
#
#    Puntaje           Politica  Prediccion  Precision
# 0        0  14-ciclico-espejo          51        NaN
# 1       -1  14-ciclico-espejo           0       49.0
# 2        1  14-ciclico-espejo          47       51.0
# 3       -1  14-ciclico-espejo          23       44.0
# 4        1  14-ciclico-espejo          47       40.5

# %% [markdown]
# **Asistencia**

# %%
dibuja_asistencia_vs(data, 'Num_predic')

# %% [markdown]
# #### Recompensa total

# %%
dibujar_puntaje_vs(data, 'Num_predic')

# %% [markdown]
# **Uso de políticas**

# %%
dibuja_usopredictores_vs(data, 'Num_predic')
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dibuja_puntajepredictor_vs(data, 'Num_predic')

# %% [markdown]
# ## Simulaciones con 9 memoria variando predictores:

# %% [markdown]
# **Obtener datos**

# %%
memorias = [9]
predictores = [1, 3, 6, 9, 12]
conectividades = ['0']
data = leer_datos(memorias, predictores, conectividades)
data.head()
# Out:
# Leyendo datos sweep memoria 9 predictores 1 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-1-0.csv...
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:17: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
# Listo
# Leyendo datos sweep memoria 9 predictores 3 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-3-0.csv...
# Listo
# Leyendo datos sweep memoria 9 predictores 6 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-6-0.csv...
# Listo
# Leyendo datos sweep memoria 9 predictores 9 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-9-0.csv...
# Listo
# Leyendo datos sweep memoria 9 predictores 12 y conectividad 0
# Cargando datos de archivo ./data/simulacion-9-12-0.csv...
# Listo
# Preparando dataframe...
#    Memoria  Num_predic  Identificador  Ronda  Agente  Estado  Puntaje  \
# 0        9           1           1200      0       0       0        0
# 1        9           1           1200      1       0       1       -1
# 2        9           1           1200      2       0       0        0
# 3        9           1           1200      3       0       1       -1
# 4        9           1           1200      4       0       0        0
#
#      Politica  Prediccion  Precision Conectividad
# 0  18-ciclico          43        NaN            0
# 1  18-ciclico         100      57.00            0
# 2  18-ciclico          54      51.50            0
# 3  18-ciclico          77      42.00            0
# 4  18-ciclico          54      37.25            0
# Shape: (5000000, 11)
# Memoria value counts: 9    5000000
# Name: Memoria, dtype: int64
# Predictores value counts: 12    1000000
# 9     1000000
# 6     1000000
# 3     1000000
# 1     1000000
# Name: Num_predic, dtype: int64
# Conectividades value counts: 0.0    5000000
# Name: Conectividad, dtype: int64
# Agente value counts: 99    50000
# 36    50000
# 26    50000
# 27    50000
# 28    50000
#       ...
# 69    50000
# 70    50000
# 71    50000
# 72    50000
# 0     50000
# Name: Agente, Length: 100, dtype: int64
#    Conectividad  Memoria  Num_predic  Identificador  Ronda  Agente  Estado  \
# 0           0.0        9           1           1200      0       0       0
# 1           0.0        9           1           1200      1       0       1
# 2           0.0        9           1           1200      2       0       0
# 3           0.0        9           1           1200      3       0       1
# 4           0.0        9           1           1200      4       0       0
#
#    Puntaje    Politica  Prediccion  Precision
# 0        0  18-ciclico          43        NaN
# 1       -1  18-ciclico         100      57.00
# 2        0  18-ciclico          54      51.50
# 3       -1  18-ciclico          77      42.00
# 4        0  18-ciclico          54      37.25

# %% [markdown]
# **Asistencia**

# %%
dibuja_asistencia_vs(data, 'Num_predic')

# %% [markdown]
# #### Recompensa total

# %%
dibujar_puntaje_vs(data, 'Num_predic')

# %% [markdown]
# **Uso de políticas**

# %%
dibuja_usopredictores_vs(data, 'Num_predic')
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dibuja_puntajepredictor_vs(data, 'Num_predic')
