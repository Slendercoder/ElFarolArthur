# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from DatosGraficos import *
# %matplotlib inline

# %% [markdown]
# ## Sin espejos

# %%
dibujar_violin(memoria=1, predictores=1, conectividad=0, espejos=False)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=3, predictores=1, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=6, predictores=1, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=9, predictores=1, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=12, predictores=1, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=1, predictores=3, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=3, predictores=3, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=6, predictores=3, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=9, predictores=3, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=12, predictores=3, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=1, predictores=6, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=3, predictores=6, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=6, predictores=6, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=9, predictores=6, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=12, predictores=6, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=1, predictores=9, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=3, predictores=9, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=6, predictores=9, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=9, predictores=9, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=12, predictores=9, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=1, predictores=12, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=3, predictores=12, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=6, predictores=12, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=9, predictores=12, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():

# %%
dibujar_violin(memoria=12, predictores=12, conectividad=0)
# Out:
# /Users/edgar/Repositorios/ElFarolArthur/DatosGraficos.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Memoria' in aux['Memoria'].unique():
