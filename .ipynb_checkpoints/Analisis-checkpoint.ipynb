# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from DatosGraficos import *
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Modelo Aleatorio

# %%
analisis1([0],[1],[0])

# %% [markdown]
# ## Modelo Arthur

# %%
analisis1([12],[1],[0])

# %%
analizar_politicas([12],[1],[0],'Puntaje>0.1',espejos=True)

# %% [markdown]
# ## Sin espejos

# %%
analisis1([12],[12],[0],espejos=False)

# %% [markdown]
# ---

# %%
analizar_politicas([12],[12],[0],'Puntaje>.9',espejos=False)
