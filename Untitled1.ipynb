# %%
import pandas as pd
import Procedatos as P
import Graficos as G
import seaborn as sns
import numpy as np

# %%
data = P.leer_datos_aleatorio([.5],[0],[100,500],verb=False)
data['Modelo'] = data['Num_agentes']
G.comparacion(data)

# %%
data1 = P.leer_datos_aleatorio([.6],[0],[100],verb=False)
data1['Modelo'] = '100 agentes'
data2 = P.leer_datos_aleatorio([.6],[0],[1000], verb=False)
data2['Modelo'] = '1000 agentes'
data = pd.concat([data1,data2])
G.comparar_desemp(data)

# %%
data1 = P.leer_datos_aleatorio([.6],[0],[100],verb=False)
data1['Modelo'] = 'Aleatorio_nuevo'
data2 = P.leer_datos([0],[1],[0], verb=False)
data2['Modelo'] = 'Aleatorio'
data = pd.concat([data1,data2])
G.comparar_desemp(data)

# %%
data1 = P.leer_datos_aleatorio([.6],[0],[100],verb=False)
data1['Modelo'] = 'p=.6'
data2 = P.leer_datos_aleatorio([.5],[0],[100],verb=False)
data2['Modelo'] = 'p=.5'
data = pd.concat([data1,data2])
G.comparar_desemp(data)
